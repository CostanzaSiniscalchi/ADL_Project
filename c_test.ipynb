# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv = 'data-2025-03-21T14_24_34.904Z.csv'

df = pd.read_csv(csv)
print(df.columns)
df
# Out:
# Index(['Site', 'PSCID', 'DCCID', 'Gender', 'Age At MRI In Months',
#        'Test Language', 'CommentID', 'Handedness Interpretation',
#        'Handedness Score', 'Visit Label', 'Visit QC Status',
#        'First Insertion'],
#       dtype='object')
#       Site        PSCID    DCCID  Gender  Age At MRI In Months Test Language  \
# 0     CONP  CONP0000000  5730499  Female                 873.8        French
# 1     CONP  CONP0000000  5730499  Female                 872.8        French
# 2     CONP  CONP0000000  5730499  Female                 885.6        French
# 3     CONP  CONP0000000  5730499  Female                 898.0        French
# 4     CONP  CONP0000000  5730499  Female                 910.0        French
# ...    ...          ...      ...     ...                   ...           ...
# 1370  CONP  CONP0000352  1283278  Female                 743.9       English
# 1371  CONP  CONP0000353  6261459    Male                 834.8        French
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Age At MRI In Months'].value_counts().index, df['Age At MRI In Months'].value_counts().values)
plt.xlabel('Age at MRI (months)')
plt.ylabel('Frequency')
plt.title('Distribution of Age at MRI (in months)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Handedness Score'].value_counts().index, df['Handedness Score'].value_counts().values)
plt.xlabel('Handedness Score')
plt.ylabel('Frequency')
plt.title('Distribution of Handedness Score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Gender'].value_counts().index, df['Gender'].value_counts().values)
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Gender')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Handedness Interpretation'].value_counts().index, df['Handedness Interpretation'].value_counts().values)
plt.xlabel('Handedness Interpretation')
plt.ylabel('Frequency')
plt.title('Distribution of Handedness Interpretation')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dates = pd.to_datetime(df['First Insertion'])

plt.figure(figsize=(10, 6))
plt.bar(dates.value_counts().index, dates.value_counts().values)
plt.xlabel('First Insertion Date')
plt.ylabel('Frequency')
plt.title('Distribution of Dates')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
