# %%
import os
import numpy as np
import re
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
base_dir = 'data_t1w_3_scans/'

# Initialize an empty list to store data
data = []
data2 = []

# %%
# Iterate over each patient's directory
for patient_dir in os.listdir(base_dir):
    patient_path = os.path.join(base_dir, patient_dir)
    if os.path.isdir(patient_path):
        
        # Iterate over each scan directory
        for scan_dir in os.listdir(patient_path):
            scan_path = os.path.join(patient_path, scan_dir)
            initial_age = None
            print(scan_path)
            if scan_path.endswith('.json'):
                
                with open(scan_path, 'r') as f:
                    json_content = f.read()

                # Fix the single quotes by replacing them with double quotes
                json_content = json_content.replace("'", '"').replace(": None", ': null')
                
                
                # Now load the fixed JSON content
                try:
                    scan_data = json.loads(json_content)
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON from {scan_path}: {e}")
                    continue
                
                # Extract relevant fields from the JSON
                m_cand_id = scan_data.get('CandID', None)
                m_gender = scan_data.get('Gender', None)
                m_language = scan_data.get('Language', None)
                m_fname = scan_path

            if os.path.isdir(scan_path):
                # print(os.listdir(scan_path))
                # Iterate over each file in the scan directory
                for file_name in os.listdir(scan_path):
                    file_path = os.path.join(scan_path, file_name)

                    # Check if the file name matches the pattern for JSON files
                    if file_name.endswith('.json'):
                        with open(file_path, 'r') as f:
                            json_content = f.read()

                        # Fix the single quotes by replacing them with double quotes
                        json_content = json_content.replace("'", '"')
                        
                        # Now load the fixed JSON content
                        try:
                            scan_data = json.loads(json_content)
                        except json.JSONDecodeError as e:
                            print(f"Error decoding JSON from {file_path}: {e}")
                            continue
                        
                        # Extract relevant fields from the JSON
                        meta = scan_data.get('Meta', {})
                        cand_id = meta.get('CandID', None)
                        visit = meta.get('Visit', None)
                        file_name_json = meta.get('File', None)
                        qc = scan_data.get('QC', None)
                        selected = scan_data.get('Selected', None)
                        caveats = scan_data.get('Caveats', [])
                        
                        if file_name == 'session.json' and scan_dir == 'PREBL00':
                            age = scan_data.get('Age_at_MRI', None)
                            print(age)
                            
                        # Process the caveats if needed (just counting them here)
                        caveat_count = len(caveats)
                        
                        # Append the data to the list
                        data.append({
                            'PatientID': patient_dir,
                            'ScanID': scan_dir,
                            'CandID': cand_id,
                            'Visit': visit,
                            'File': file_name_json,
                            'QC': qc,
                            'Selected': selected,
                            'CaveatCount': caveat_count,
                            'FileName': file_name
                        })
        # Append the data to the list
        data2.append({
            'CandID': m_cand_id,
            'File': m_fname,
            'Gender': m_gender,
            'Language': m_language,
            'Initial Age in Months': age,
            'Initial Age in Years': float(age)//12
        })        

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data)
df2 = pd.DataFrame(data2)

df.to_csv('preventad_patients.csv')
df2.to_csv('preventad_candidates.csv')
df
# Out:
# data_t1w_3_scans/9539210/candidate.json
# data_t1w_3_scans/9539210/PREBL00
# 780.2
# data_t1w_3_scans/9539210/PREFU12
# data_t1w_3_scans/9539210/PREFU24
# data_t1w_3_scans/6008569/candidate.json
# data_t1w_3_scans/6008569/PREBL00
# 787.8
# data_t1w_3_scans/6008569/PREFU12
# data_t1w_3_scans/6008569/PREFU24
# data_t1w_3_scans/4276824/candidate.json
# data_t1w_3_scans/4276824/PREBL00
# 768.6
# data_t1w_3_scans/4276824/PREFU12
# data_t1w_3_scans/4276824/PREFU24
# data_t1w_3_scans/9909448/candidate.json
# data_t1w_3_scans/4943065/candidate.json
# data_t1w_3_scans/4943065/PREFU24
# data_t1w_3_scans/2924615/candidate.json
# data_t1w_3_scans/2924615/PREBL00
# 804.2
# data_t1w_3_scans/2924615/PREFU12
# data_t1w_3_scans/2924615/PREFU24
# data_t1w_3_scans/7863867/candidate.json
# data_t1w_3_scans/7863867/PREBL00
# 699.1
# data_t1w_3_scans/7863867/PREFU12
# data_t1w_3_scans/7863867/PREFU24
# data_t1w_3_scans/9380004/candidate.json
# data_t1w_3_scans/9380004/PREBL00
# 808
# data_t1w_3_scans/9380004/PREFU12
# data_t1w_3_scans/9380004/PREFU24
# data_t1w_3_scans/1635604/candidate.json
# data_t1w_3_scans/1635604/PREFU24
# data_t1w_3_scans/4136011/candidate.json
# data_t1w_3_scans/4136011/PREFU12
# data_t1w_3_scans/4136011/PREFU24
# data_t1w_3_scans/7550757/candidate.json
# data_t1w_3_scans/7550757/PREFU24
# data_t1w_3_scans/8686311/candidate.json
# data_t1w_3_scans/8686311/PREBL00
# 709.7
# data_t1w_3_scans/8686311/PREFU12
# data_t1w_3_scans/8686311/PREFU24
# data_t1w_3_scans/2599481/candidate.json
# data_t1w_3_scans/2599481/PREBL00
# 885
# data_t1w_3_scans/2599481/PREFU12
# data_t1w_3_scans/2599481/PREFU24
# data_t1w_3_scans/3705605/candidate.json
# data_t1w_3_scans/3705605/PREFU12
# data_t1w_3_scans/3705605/PREFU24
# data_t1w_3_scans/4210489/candidate.json
# data_t1w_3_scans/4210489/PREBL00
# 759.7
# data_t1w_3_scans/4210489/PREFU12
# data_t1w_3_scans/4210489/PREFU24
# data_t1w_3_scans/7672530/candidate.json
# data_t1w_3_scans/7672530/PREBL00
# 722
# data_t1w_3_scans/7672530/PREFU12
# data_t1w_3_scans/7672530/PREFU24
# data_t1w_3_scans/5730499/candidate.json
# data_t1w_3_scans/5730499/PREBL00
# 873.8
# data_t1w_3_scans/5730499/PREFU12
# data_t1w_3_scans/5730499/PREFU24
# data_t1w_3_scans/4532706/candidate.json
# data_t1w_3_scans/4532706/PREBL00
# 838.9
# data_t1w_3_scans/4532706/PREFU12
# data_t1w_3_scans/4532706/PREFU24
# data_t1w_3_scans/6433158/candidate.json
# data_t1w_3_scans/6433158/PREBL00
# 877.5
# data_t1w_3_scans/6433158/PREFU12
# data_t1w_3_scans/6433158/PREFU24
#     PatientID   ScanID   CandID    Visit  \
# 0     9539210  PREBL00     None     None
# 1     9539210  PREBL00  9539210  PREBL00
# 2     9539210  PREFU12     None     None
# 3     9539210  PREFU12  9539210  PREFU12
# 4     9539210  PREFU24     None     None
# ..        ...      ...      ...      ...
# 355   6433158  PREFU12  6433158  PREFU12
# 356   6433158  PREFU12     None     None
# 357   6433158  PREFU24     None     None
# 358   6433158  PREFU24  6433158  PREFU24
# 359   6433158  PREFU24  6433158  PREFU24
#
#                                                   File    QC Selected  \
# 0                                                 None  None     None
# 1    preventad_9539210_PREBL00_t1w_001_t1w-defaced_...  Pass     true
# 2                                                 None  None     None
# 3    preventad_9539210_PREFU12_t1w_001_t1w-defaced_...  Pass     true
# 4                                                 None  None     None
# ..                                                 ...   ...      ...
# 355  preventad_6433158_PREFU12_t1w_001_t1w-defaced_...  Pass     true
# 356                                               None  None     None
# 357                                               None  None     None
# 358  preventad_6433158_PREFU24_t1w_002_t1w-defaced_...  Pass     true
# 359  preventad_6433158_PREFU24_t1w_001_t1w-defaced_...  Pass     true
#
#      CaveatCount                                           FileName
# 0              0                                       session.json
# 1              1  preventad_9539210_PREBL00_t1w_001_t1w-defaced_...
# 2              0                                       session.json
# 3              1  preventad_9539210_PREFU12_t1w_001_t1w-defaced_...
# 4              0                                       session.json
# ..           ...                                                ...
# 355            1  preventad_6433158_PREFU12_t1w_001_t1w-defaced_...
# 356            0                                       session.json
# 357            0                                       session.json
# 358            1  preventad_6433158_PREFU24_t1w_002_t1w-defaced_...
# 359            1  preventad_6433158_PREFU24_t1w_001_t1w-defaced_...
#
# [360 rows x 9 columns]

# %%
data = []
# Iterate over each patient's directory
for patient_dir in os.listdir(base_dir):
    patient_path = os.path.join(base_dir, patient_dir)
    if os.path.isdir(patient_path):
        m0 = 0
        m12 = 0
        m24 = 0
        # Iterate over each scan directory
        for scan_dir in os.listdir(patient_path):

            scan_path = os.path.join(patient_path, scan_dir)
            if os.path.isdir(scan_path):
                # print(os.listdir(scan_path))
                # Iterate over each file in the scan directory
               
                if scan_dir == 'PREBL00':
                    m0 = len([file for file in os.listdir(scan_path) if not file.endswith('.json')])
                elif scan_dir == 'PREFU12':
                    m12 = len([file for file in os.listdir(scan_path) if not file.endswith('.json')])
                else:
                    m24 = len([file for file in os.listdir(scan_path) if not file.endswith('.json')]) 
        # Append the data to the list
        data.append({
            'PatientID': patient_dir,
            'PREBL00': m0,
            'PREFU12': m12,
            'PREFU24': m24,
        })
                    

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data)

df.to_csv('preventad_filestats.csv')
df
# Out:
#    PatientID  PREBL00  PREFU12  PREFU24
# 0    9539210        1        1        2
# 1    6008569        2        2        4
# 2    4276824        2        2        4
# 3    9909448        4        2        4
# 4    2887681        2        2        4
# 5    5030375        2        2        4
# 6    8478383        2        2        4
# 7    1984879        2        2        6
# 8    8052813        2        2        4
# 9    4773593        2        2        4
# 10   3343577        2        2        4
# 11   7125565        2        2        4
# 12   5158901        0        0        3
# 13   4210363        2        2        4
# 14   3301724        2        2        4
# 15   2963960        2        2        4
# 16   5187625        2        2        4
# 17   7755697        2        2        4
# 18   4317780        2        2        4
# 19   1004359        2        2        0
# 20   2823276        2        2        2
# 21   7237992        2        4        4
# 22   3475739        2        2        4
# 23   1369125        0        0        0
# 24   6967785        2        2        4
# 25   1016072        2        2        4
# 26   3048898        2        2        4
# 27   3191214        2        2        4
# 28   3730353        2        2        4
# 29   3162878        1        2        2
# 30   3692881        2        0        4
# 31   9827494        2        2        4
# 32   4052945        2        2        4
# 33   5160587        2        2        4
# 34   4040157        2        2        4
# 35   5692079        1        2        4
# 36   3165520        1        1        2
# 37   8120729        1        1        2
# 38   7760229        2        2        4
# 39   2448082        0        1        2
# 40   4943065        0        0        2
# 41   2924615        2        1        4
# 42   7863867        1        1        2
# 43   9380004        1        2        4
# 44   1635604        0        0        3
# 45   4136011        0        1        2
# 46   7550757        0        0        2
# 47   8686311        2        2        4
# 48   2599481        2        2        4
# 49   3705605        0        1        2
# 50   4210489        2        2        4
# 51   7672530        4        2        6
# 52   5730499        1        1        4
# 53   4532706        2        2        2
# 54   6433158        2        1        2
